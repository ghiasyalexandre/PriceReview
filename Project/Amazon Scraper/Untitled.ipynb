# %%
pip install keepa
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import keepa
import pyodbc
import sqlalchemy
accesskey = '3lhbjjh6qaue3i1h9llq1qn1et52p1u482j3q0kqu087l2vickfugl95951p0gf8' # enter real access key here

api = await keepa.AsyncKeepa.create(accesskey)

# %%
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-7600c8b786e3> in <module>
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-57> in load_ext(self, module_str)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ...

# %%
asins = ['B07B41WS48']
products = await api.query(asins, offers=20)

print('Product is ' + products[0]['title'])
#print('The cost is'+ products[0]['offers'])

newprice = products[0]['data']['NEW']
print('Amazon sells this item for $' + str(newprice[1]))
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Product is AMD Ryzen 5 2600 Processor with Wraith Stealth Cooler - YD2600BBAFBOX
# Amazon sells this item for $199.0

# %%
keepa.plot_product(products[0])
# Out:
# ...
# 100%|██████████| 1/1 [07:07<00:00, 427.79s/it]
